# %%
from matplotlib.lines import Line2D
from src import segment, fit, draw
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # HYPER PARAMETER

# %%
if IS_MASTER:
    DATA_DIR = 'data/' #
    MAX_ERROR = 1

# %%
data_df = pd.read_csv("data/SKAB-data/valve1/2.csv", sep=(";"))

# %%
data = list(data_df["Accelerometer1RMS"].values)

# %%
change_points = list(data_df[data_df["changepoint"]==1.0].index.values)
anomalies = list(data_df[data_df["anomaly"]==1.0].index.values)

# %%
ts_segments, line_segments = segment.get_ts_segments(segment.bottomupsegment, data, fit.regression, fit.sumsquared_error, max_error)

# %%
plt.figure(figsize=(20,10))
draw.draw_plot(data,"Top-down with regression")
for cp in anomalies:
    plt.axvline(x=cp)

# %%
figure(figsize=(20,10))
draw_plot(data,"Top-down with regression")

# %%
data_df[data_df["anomaly"]==1.0]
